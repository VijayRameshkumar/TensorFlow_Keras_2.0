# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayRameshkumar/TensorFlow_Keras_2.0/blob/master/01_mnist_fashion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.0-rc0
# !pip install tensorflow-gpu==2.0.0-rc0

# %%
import tensorflow as tf
from tensorflow import keras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.0.0-rc0

# %%
mnist = keras.datasets.fashion_mnist

# %%
type(mnist)
# Out:
# tensorflow.python.util.module_wrapper.TFModuleWrapper

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
print(x_train.shape, y_train.shape)
# Out:
# (60000, 28, 28) (60000,)

# %%
y_train
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
class_names = {'0' : 'T_shirt/Top', '1' : 'Trouser', '2' : 'Pullover', '3' : 'Dress', '4' : 'Coat', '5' : 'Sandal', '6' : 'Shirt', '7' : 'Sneaker', '8' : 'Bag', '9' : 'Ankle_boot'}

# %% [markdown]
# # **Data Exploration**

# %%
print(x_train.shape, x_test.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28)

# %%
plt.figure()
plt.imshow(x_train[0]);

# %%
y_train
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
x_train = x_train / 255.0 # Normalize the data 0 to 1

# %%
plt.figure()
plt.imshow(x_train[1]);
plt.colorbar();

# %% [markdown]
# # **Build the model with TF 2.0**

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense

# %%
model = Sequential()
model.add(Flatten(input_shape = (28,28)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1290
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Model Compilation**
# - Loss Function
# - Optimizer
# - Metrics

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.5007 - accuracy: 0.8218
# Epoch 2/10
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.3758 - accuracy: 0.8659
# Epoch 3/10
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.3370 - accuracy: 0.8778
# Epoch 4/10
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.3133 - accuracy: 0.8853
# Epoch 5/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.2955 - accuracy: 0.8914
# Epoch 6/10
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.2797 - accuracy: 0.8969
# Epoch 7/10
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.2694 - accuracy: 0.9003
# Epoch 8/10
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.2554 - accuracy: 0.9050
# Epoch 9/10
# ...

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(test_acc)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict_classes(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.845

# %%
pred = y_pred.tolist()
prediction = []
for i in pred:
  i = str(i)
  prediction.append(i)

# %%
classes = []
for i in prediction:
  classes.append(class_names[i])
classes
# Out:
# ['Ankle_boot',
#  'Pullover',
#  'Trouser',
#  'Trouser',
#  'T_shirt/Top',
#  'Trouser',
#  'Coat',
#  'Shirt',
#  'Sandal',
#  'Sneaker',
#  'Coat',
#  'Sandal',
#  'Sandal',
#  'Dress',
#  'Coat',
#  'Trouser',
#  'Pullover',
#  'Pullover',
#  'Bag',
#  'T_shirt/Top',
#  'Pullover',
#  'Sandal',
#  'Sneaker',
#  'Sandal',
#  'Trouser',
#  'Coat',
#  'Shirt',
#  'T_shirt/Top',
#  'Ankle_boot',
#  'Coat',
#  'Bag',
#  'Bag',
#  'Dress',
#  'Dress',
#  'Bag',
#  'T_shirt/Top',
#  'Sneaker',
#  'Sandal',
#  'Sneaker',
#  'Ankle_boot',
#  'T_shirt/Top',
#  'Trouser',
#  'Shirt',
#  'Ankle_boot',
#  'Shirt',
#  'Sneaker',
#  'Pullover',
#  'Trouser',
#  'Coat',
#  'Shirt',
#  'Coat',
#  'Coat',
#  'Sandal',
#  'Bag',
#  'Pullover',
#  'Pullover',
#  'Bag',
#  'Coat',
#  'Bag',
#  'T_shirt/Top',
#  'Sneaker',
#  'Sneaker',
#  'Bag',
#  'Sandal',
#  'Trouser',
#  'Trouser',
#  'Coat',
#  'Coat',
#  'Sneaker',
#  'Bag',
#  'Sneaker',
#  'T_shirt/Top',
#  'Pullover',
#  'Shirt',
#  'Coat',
# ...
